# %% [markdown]
# which languages are most used and most sought after by developers?
#
# What are the main differences between female and male developers?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
# %matplotlib inline

df = pd.read_csv('./survey_results_public.csv')
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# 3                      Employed full-time
# 4                      Employed full-time
#
#                                      FormalEducation  \
# 0                                   Secondary school
# 1  Some college/university study without earning ...
# 2                                  Bachelor's degree
# 3                                    Doctoral degree
# 4                                    Master's degree
#
#                                   MajorUndergrad  \
# 0                                            NaN
# 1       Computer science or software engineering
# 2       Computer science or software engineering
# 3  A non-computer-focused engineering discipline
# 4       Computer science or software engineering
#
#                                           HomeRemote  \
# 0                                                NaN
# 1              More than half, but not all, the time
# 2  Less than half the time, but at least one day ...
# 3  Less than half the time, but at least one day ...
# 4                                              Never
#
#                 CompanySize  ... StackOverflowMakeMoney Gender  \
# 0                       NaN  ...      Strongly disagree   Male
# 1        20 to 99 employees  ...      Strongly disagree   Male
# 2  10,000 or more employees  ...               Disagree   Male
# 3  10,000 or more employees  ...               Disagree   Male
# 4        10 to 19 employees  ...                    NaN    NaN
#
#   HighestEducationParents                          Race         SurveyLong  \
# 0             High school  White or of European descent  Strongly disagree
# 1       A master's degree  White or of European descent     Somewhat agree
# 2   A professional degree  White or of European descent     Somewhat agree
# 3       A doctoral degree  White or of European descent              Agree
# 4                     NaN                           NaN                NaN
#
#   QuestionsInteresting QuestionsConfusing InterestedAnswers    Salary  \
# 0       Strongly agree           Disagree    Strongly agree       NaN
# 1       Somewhat agree           Disagree    Strongly agree       NaN
# 2                Agree           Disagree             Agree  113750.0
# 3                Agree     Somewhat agree    Strongly agree       NaN
# 4                  NaN                NaN               NaN       NaN
#
#    ExpectedSalary
# 0             NaN
# 1         37500.0
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 154 columns]

# %%
columns_of_interest = [
    'Professional',
    'Country',
    'University',
    'EmploymentStatus',
    'DeveloperType',
    'HaveWorkedLanguage',
    'WantWorkLanguage',
    'Gender',
    'Salary'
]

sub_df = df.loc[:, columns_of_interest]

# %%
sub_df.head()
# Out:
#                                         Professional         Country  \
# 0                                            Student   United States
# 1                                            Student  United Kingdom
# 2                             Professional developer  United Kingdom
# 3  Professional non-developer who sometimes write...   United States
# 4                             Professional developer     Switzerland
#
#        University                        EmploymentStatus  \
# 0              No  Not employed, and not looking for work
# 1  Yes, full-time                      Employed part-time
# 2              No                      Employed full-time
# 3              No                      Employed full-time
# 4              No                      Employed full-time
#
#                                        DeveloperType  \
# 0                                                NaN
# 1                                                NaN
# 2                                              Other
# 3                                                NaN
# 4  Mobile developer; Graphics programming; Deskto...
#
#               HaveWorkedLanguage         WantWorkLanguage Gender    Salary
# 0                          Swift                    Swift   Male       NaN
# 1  JavaScript; Python; Ruby; SQL  Java; Python; Ruby; SQL   Male       NaN
# 2              Java; PHP; Python          C; Python; Rust   Male  113750.0
# 3         Matlab; Python; R; SQL   Matlab; Python; R; SQL   Male       NaN
# 4                            NaN                      NaN    NaN       NaN

# %%
countries = sub_df.groupby('Country').size().to_dict()
wordcloud = WordCloud(width=900,height=500, background_color='white').generate_from_frequencies(countries)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
gen_sub_df
# Out:
#                                             Professional         Country  \
# 0                                                Student   United States
# 1                                                Student  United Kingdom
# 2                                 Professional developer  United Kingdom
# 3      Professional non-developer who sometimes write...   United States
# 6      Professional non-developer who sometimes write...   United States
# ...                                                  ...             ...
# 51386                             Professional developer         Romania
# 51387                             Professional developer   United States
# 51388                                            Student       Venezuela
# 51390                             Professional developer   United States
# 51391  Professional non-developer who sometimes write...         Ireland
#
#            University                        EmploymentStatus  \
# 0                  No  Not employed, and not looking for work
# 1      Yes, full-time                      Employed part-time
# 2                  No                      Employed full-time
# 3                  No                      Employed full-time
# 6                  No                      Employed full-time
# ...               ...                                     ...
# 51386              No                      Employed full-time
# 51387              No                      Employed full-time
# 51388  Yes, full-time                      Employed full-time
# 51390              No                      Employed full-time
# 51391              No                      Employed full-time
#
#                                            DeveloperType  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                  Other
# 3                                                    NaN
# 6                                                    NaN
# ...                                                  ...
# 51386  Web developer; Mobile developer; Developer wit...
# 51387  Web developer; Developer with a statistics or ...
# 51388                                                NaN
# 51390                    Web developer; Mobile developer
# 51391                                                NaN
#
#                                HaveWorkedLanguage  \
# 0                                           Swift
# 1                   JavaScript; Python; Ruby; SQL
# 2                               Java; PHP; Python
# 3                          Matlab; Python; R; SQL
# 6                                  Matlab; Python
# ...                                           ...
# 51386         C++; C#; Java; JavaScript; PHP; SQL
# 51387    C#; JavaScript; Python; SQL; VB.NET; VBA
# 51388                                   Java; SQL
# 51390                      JavaScript; PHP; Swift
# 51391  Java; JavaScript; PHP; Python; Ruby; Swift
#
#                                         WantWorkLanguage Gender    Salary
# 0                                                  Swift   Male       NaN
# 1                                Java; Python; Ruby; SQL   Male       NaN
# 2                                        C; Python; Rust   Male  113750.0
# 3                                 Matlab; Python; R; SQL   Male       NaN
# 6              JavaScript; Julia; Matlab; Python; R; SQL   Male       NaN
# ...                                                  ...    ...       ...
# 51386                 C++; C#; Go; Java; JavaScript; PHP   Male       NaN
# 51387  C#; Python; R; Ruby; Rust; Scala; TypeScript; ...   Male   58000.0
# 51388  C#; Java; JavaScript; PHP; Python; Ruby; SQL; ...   Male       NaN
# 51390                           Clojure; Erlang; Haskell   Male   40000.0
# 51391                                                NaN   Male       NaN
#
# [35047 rows x 9 columns]

# %%
def get_unique_group_type(df, column):
    return df[column].str.split('; ').explode('index').value_counts().index.to_list()

# %%
def get_count_group_type(df, column, groups):
    group_count = dict()
    for group in groups:
        group_count[group] = df[column].apply(lambda s: group in s.split(';')).sum()
    return group_count

# %%
unique_developer_types = get_unique_group_type(gen_sub_df, 'DeveloperType')
developer_types = get_count_group_type(gen_sub_df, 'Gender', unique_genders)

# %%
developer_types = get_unique_group_type(gen_sub_df, 'DeveloperType')

# %%
unique_genders = get_unique_group_type(gen_sub_df, 'Gender')
genders = get_count_group_type(gen_sub_df, 'Gender', unique_genders)

plt.figure(figsize=(10,6))
plt.bar(*zip(*genders.items()))
plt.show()
